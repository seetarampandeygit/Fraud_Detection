# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\class-grades.csv", header=0)
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    30.00     63.15  48.89
# 3       7       81.22     96.06    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
df.shape
# Out:
# (99, 6)

# %%
df.iloc[2]
# Out:
# Prefix         8.00
# Assignment    83.70
# Tutorial      83.17
# Midterm       30.00
# TakeHome      63.15
# Final         48.89
# Name: 2, dtype: float64

# %%
row_5m= df[df.iloc[:].isna().sum(axis=1)<4]

# %%
row_5m.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    30.00     63.15  48.89
# 3       7       81.22     96.06    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
df= df[df.iloc[:].isnull().sum(axis=1)==0]

# %%
df.isnull().sum()
# Out:
# Prefix        0
# Assignment    0
# Tutorial      0
# Midterm       0
# TakeHome      0
# Final         0
# dtype: int64

# %%
row_5m.isnull().sum()
# Out:
# Prefix         0
# Assignment     0
# Tutorial      10
# Midterm       14
# TakeHome       7
# Final          3
# dtype: int64

# %%
df= df[~(df.iloc[:].isna().sum(axis=1)>4)]

# %%
df.head()
# Out:
#    Prefix  Assignment  Tutorial  Midterm  TakeHome  Final
# 0       5       57.14     34.09    64.38     51.48  52.50
# 1       8       95.05    105.49    67.50     99.07  68.33
# 2       8       83.70     83.17    30.00     63.15  48.89
# 3       7       81.22     96.06    49.38    105.93  80.56
# 4       8       91.32     93.64    95.00    107.41  73.89

# %%
df.isnull().sum()
# Out:
# Prefix         0
# Assignment     0
# Tutorial      10
# Midterm       14
# TakeHome       7
# Final          3
# dtype: int64

# %%
customer=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\cust_dimen.csv", header=0)

# %%
customer.head(15)
# Out:
#          Customer_Name Province   Region Customer_Segment  Cust_id
# 0   MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS   Cust_1
# 1         BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER   Cust_2
# 2        CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE   Cust_3
# 3       CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER   Cust_4
# 4         CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE   Cust_5
# 5       MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE   Cust_6
# 6      DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE   Cust_7
# 7      NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE   Cust_8
# 8          CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE   Cust_9
# 9        CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_10
# 10    ALLEN ROSENBLATT  NUNAVUT  NUNAVUT   SMALL BUSINESS  Cust_11
# 11     SYLVIA FOULSTON  NUNAVUT  NUNAVUT      HOME OFFICE  Cust_12
# 12         JIM RADFORD  NUNAVUT  NUNAVUT        CORPORATE  Cust_13
# ...

# %%
customer.Cust_id= customer.Cust_id.apply(lambda x: x[5:])

# %%
customer.head(15)
# Out:
#          Customer_Name Province   Region Customer_Segment Cust_id
# 0   MUHAMMED MACINTYRE  NUNAVUT  NUNAVUT   SMALL BUSINESS       1
# 1         BARRY FRENCH  NUNAVUT  NUNAVUT         CONSUMER       2
# 2        CLAY ROZENDAL  NUNAVUT  NUNAVUT        CORPORATE       3
# 3       CARLOS SOLTERO  NUNAVUT  NUNAVUT         CONSUMER       4
# 4         CARL JACKSON  NUNAVUT  NUNAVUT        CORPORATE       5
# 5       MONICA FEDERLE  NUNAVUT  NUNAVUT        CORPORATE       6
# 6      DOROTHY BADDERS  NUNAVUT  NUNAVUT      HOME OFFICE       7
# 7      NEOLA SCHNEIDER  NUNAVUT  NUNAVUT      HOME OFFICE       8
# 8          CARLOS DALY  NUNAVUT  NUNAVUT      HOME OFFICE       9
# 9        CLAUDIA MINER  NUNAVUT  NUNAVUT   SMALL BUSINESS      10
# 10    ALLEN ROSENBLATT  NUNAVUT  NUNAVUT   SMALL BUSINESS      11
# 11     SYLVIA FOULSTON  NUNAVUT  NUNAVUT      HOME OFFICE      12
# 12         JIM RADFORD  NUNAVUT  NUNAVUT        CORPORATE      13
# ...

# %%
rating= pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\rating_final.csv", header=0)

# %%
rating.head(15)
# Out:
#    userID  placeID  rating  food_rating  service_rating
# 0   U1077   135085       2            2               2
# 1   U1077   135038       2            2               1
# 2   U1077   132825       2            2               2
# 3   U1077   135060       1            2               2
# 4   U1068   135104       1            1               2
# 5   U1068   132740       0            0               0
# 6   U1068   132663       1            1               1
# 7   U1068   132732       0            0               0
# 8   U1068   132630       1            1               1
# 9   U1067   132584       2            2               2
# 10  U1067   132733       1            1               1
# 11  U1067   132732       1            2               2
# 12  U1067   132630       1            0               1
# 13  U1067   135104       0            0               0
# 14  U1067   132560       1            0               0

# %%
rating.shape
# Out:
# (1254, 5)

# %%
rating['userID'].unique()
# Out:
# array(['U1077', 'U1068', 'U1067', 'U1044', 'U1070', 'U1031', 'U1082',
#        'U1023', 'U1060', 'U1015', 'U1123', 'U1021', 'U1026', 'U1083',
#        'U1108', 'U1012', 'U1093', 'U1030', 'U1066', 'U1127', 'U1017',
#        'U1100', 'U1133', 'U1118', 'U1072', 'U1080', 'U1063', 'U1074',
#        'U1117', 'U1020', 'U1051', 'U1055', 'U1053', 'U1035', 'U1064',
#        'U1081', 'U1001', 'U1014', 'U1088', 'U1056', 'U1134', 'U1106',
#        'U1126', 'U1124', 'U1018', 'U1125', 'U1119', 'U1076', 'U1022',
#        'U1094', 'U1116', 'U1105', 'U1075', 'U1007', 'U1115', 'U1024',
#        'U1132', 'U1005', 'U1120', 'U1004', 'U1037', 'U1052', 'U1036',
#        'U1038', 'U1071', 'U1114', 'U1084', 'U1049', 'U1019', 'U1069',
#        'U1113', 'U1104', 'U1079', 'U1045', 'U1009', 'U1016', 'U1047',
#        'U1095', 'U1034', 'U1078', 'U1099', 'U1008', 'U1040', 'U1121',
#        'U1110', 'U1042', 'U1013', 'U1054', 'U1111', 'U1128', 'U1062',
# ...

# %%
rating=rating.drop_duplicates(subset=['userID'])

# %%
rating.head(15)
# Out:
#    userID  placeID  rating  food_rating  service_rating
# 0   U1077   135085       2            2               2
# 4   U1068   135104       1            1               2
# 9   U1067   132584       2            2               2
# 28  U1044   132583       1            2               1
# 29  U1070   132608       2            2               1
# 32  U1031   132663       0            0               0
# 35  U1082   132630       1            1               1
# 36  U1023   132715       0            0               0
# 44  U1060   132564       2            2               2
# 48  U1015   135071       0            0               0
# 49  U1123   132733       1            2               1
# 57  U1021   132740       2            2               1
# 58  U1026   132626       2            2               2
# 62  U1083   135034       2            2               2
# 65  U1108   135075       2            2               2

# %%
rating.shape
# Out:
# (136, 5)

# %%
rating.reset_index()
# Out:
#      index userID  placeID  rating  food_rating  service_rating
# 0        0  U1077   135085       2            2               2
# 1        4  U1068   135104       1            1               2
# 2        9  U1067   132584       2            2               2
# 3       28  U1044   132583       1            2               1
# 4       29  U1070   132608       2            2               1
# ..     ...    ...      ...     ...          ...             ...
# 131   1229  U1065   132626       1            0               1
# 132   1235  U1039   132626       2            2               1
# 133   1239  U1130   132654       0            0               0
# 134   1243  U1043   132608       1            1               1
# 135   1245  U1011   132717       2            2               1
#
# [136 rows x 6 columns]

# %%
rating1= pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\rating_final.csv", header=0)

# %%
rating1.head(20)
# Out:
#    userID  placeID  rating  food_rating  service_rating
# 0   U1077   135085       2            2               2
# 1   U1077   135038       2            2               1
# 2   U1077   132825       2            2               2
# 3   U1077   135060       1            2               2
# 4   U1068   135104       1            1               2
# 5   U1068   132740       0            0               0
# 6   U1068   132663       1            1               1
# 7   U1068   132732       0            0               0
# 8   U1068   132630       1            1               1
# 9   U1067   132584       2            2               2
# 10  U1067   132733       1            1               1
# 11  U1067   132732       1            2               2
# 12  U1067   132630       1            0               1
# 13  U1067   135104       0            0               0
# 14  U1067   132560       1            0               0
# 15  U1077   132825       2            2               2
# ...

# %%
rating1.shape
# Out:
# (1254, 5)

# %%
rating1_update= rating1.drop_duplicates(subset=['userID', 'placeID', 'rating', 'food_rating','service_rating'])

# %%
rating1_update.shape
# Out:
# (1149, 5)

# %%
emp= pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\employment-data.csv")

# %%
emp.head()
# Out:
#    Serial Number Name of the Candidate           Resume ID  \
# 0              1            eswaran.k.  2202ca2e0bf1584674
# 1              2                   Raj  4ab9edcf1d929e2204
# 2              3          arun kumar.v  00d88e536f048e2a42
# 3              4              dhayalan  5b687d5a11bce58812
# 4              5             SUMAN ROY  6ab3d45252407fb581
#
#                                       Postal Address      Telephone No.  \
# 0  1/403,NORTH STREET PALLAPATTI,SIVAKSI,VIRUDHU ...              91 44
# 1  21/10, Saradambal street, \r\r\nReddykuppam Ro...                NaN
# 2  V. Arun Kumar,\r\r\n4/283, Malamanur,\r\r\nPot...                NaN
# 3      Permanent Address : S/o.K.Sundaresan,Ariyalur                 44
# 4                    somu_somu011@yahoo.co.in,Mysore  91 44 08213293121
#
#      Mobile No. Date of Birth                     Email Work Experience  \
# 0  8.908314e+09  '24 Sep 1984     eswaranke05@gmail.com       4 Year(s)
# ...

# %%
emp.columns
# Out:
# Index(['Serial Number', 'Name of the Candidate', 'Resume ID', 'Postal Address',
#        'Telephone No.', 'Mobile No.', 'Date of Birth', 'Email',
#        'Work Experience', 'Resume Title', 'Current Location',
#        'Preferred Location', 'Current Employer', 'Current Designation',
#        'Annual Salary', 'U.G. Course', 'P. G. Course', 'Post P. G. Course',
#        'Last Active Date', 'Comment 1'],
#       dtype='object')

# %%
c_loc= emp[['Current Location']]

# %%
c_loc.head()
# Out:
#   Current Location
# 0          Chennai
# 1          Chennai
# 2            Salem
# 3          Chennai
# 4          Chennai

# %%
c_loc_count=c_loc['Current Location'].value_counts()

# %%
df2=pd.DataFrame(c_loc_count)

# %%
df2.head()
# Out:
#                   count
# Current Location
# Chennai           29648
# Coimbatore         3569
# Trichy             2073
# Madurai            1460
# Salem              1344

# %%
df2['Rank']= range(1,len(df2)+1)

# %%
df2.head()
# Out:
#                   count  Rank
# Current Location
# Chennai           29648     1
# Coimbatore         3569     2
# Trichy             2073     3
# Madurai            1460     4
# Salem              1344     5

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 327 entries, Chennai to Gudiyattam
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   327 non-null    int64
#  1   Rank    327 non-null    int64
# dtypes: int64(2)
# memory usage: 7.7+ KB

# %%
#sns.jointplot(data=inp2, x=inp2['Price'], y=inp2['Rating'], kind='reg')
sns.jointplot(data=df2, x=df2['Rank'], y=df2['count'], kind='reg')
plt.show()

# %%
plt.scatter(np.log(df2['Rank']), np.log(df2['count']))
plt.show()

# %%
sns.countplot(data=emp, x=emp['Current Location'])
plt.show()

# %%
ten=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\tendulkar_ODI.csv")

# %%
ten
# Out:
#      Unnamed: 0 Runs Mins   BF  4s 6s      SR Pos Dismissal Inns  \
# 0             1    0    -    2   0  0       0   5    caught    2
# 1             2    0    2    2   0  0       0   5    caught    2
# 2             3   36   51   39   5  0    92.3   6    caught    1
# 3             4   19   38   35   1  1   54.28   4    bowled    2
# 4             5   31   31   26   3  0  119.23   6    bowled    2
# ..          ...  ...  ...  ...  .. ..     ...  ..       ...  ...
# 290         291   18   21   14   2  0  128.57   2    caught    2
# 291         292    2    9    6   0  0   33.33   2    caught    2
# 292         293    3   21   12   0  0      25   2    caught    2
# 293         294   14   34   15   2  0   93.33   2   run out    2
# 294         295  114  205  147  12  1   77.55   2    caught    1
#
#         Opposition      Ground Start Date
# 0       v Pakistan  Gujranwala  18-Dec-89
# 1    v New Zealand     Dunedin   1-Mar-90
# 2    v New Zealand  Wellington   6-Mar-90
# ...

# %%
print(ten.Runs.value_counts())
# Out:
# Runs
# 1      16
# 2      14
# 0      12
# 4       9
# 21      8
#        ..
# 139     1
# 70*     1
# 101     1
# 87*     1
# 85      1
# Name: count, Length: 118, dtype: int64

# %%
ten.Runs.unique()
# Out:
# array(['0', '36', '19', '31', '53', '30', 'DNB', '4', '62', '1', '57',
#        '21', '69', '11', '84', '39', '15', '10', '22', '32', '23', '82*',
#        '3', '24', '5', '34', '8*', '25', '26*', '2', '28*', '11*', '52',
#        '82', '63', '40', '6', '8', '115', '66', '54', '88', '105', '13',
#        '7', '65', '127*', '70', '90', '137', '110', '64', '28', '67',
#        '114', '14', '45', '44', '65*', '9', '117', '27', '100', '33',
#        '18', '100*', '17', '128', '29', '37', '120', '186*', '12', '26',
#        '122', '93', '146', '35', '139', '70*', '101', '38', '68', '87*',
#        '34*', '81', '89', '102', '86', '141', '74', '16', '47', '123',
#        '67*', '42', '95', '55', '60', 'TDNB', '99', '71', '94', '43',
#        '79', '72', '97', '117*', '91', '50', '20', '163*', '138', '175',
#        '96*', '200*', '111', '85'], dtype=object)

# %%
ten.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 295 entries, 0 to 294
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  295 non-null    int64
#  1   Runs        295 non-null    object
#  2   Mins        295 non-null    object
#  3   BF          295 non-null    object
#  4   4s          295 non-null    object
#  5   6s          295 non-null    object
#  6   SR          295 non-null    object
#  7   Pos         295 non-null    object
#  8   Dismissal   295 non-null    object
#  9   Inns        295 non-null    object
#  10  Opposition  295 non-null    object
#  11  Ground      295 non-null    object
#  12  Start Date  295 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 30.1+ KB

# %%
ten.Runs=ten.Runs.apply(lambda x: x[0:-1])

# %%
ten.Runs.unique()
# Out:
# array(['', '3', '1', '5', 'DN', '6', '2', '8', '82', '26', '28', '11',
#        '4', '10', '127', '7', '9', '13', '65', '100', '12', '186', '14',
#        '70', '87', '34', '67', 'TDN', '117', '163', '17', '96', '200'],
#       dtype=object)

# %%
ten=ten[~(ten['Runs']=='') & ~(ten['Runs']=='TDN')]

# %%
ten=ten[~(ten['Runs']=='DN')]

# %%
ten.Runs.unique()
# Out:
# array(['3', '1', '5', '6', '2', '8', '82', '26', '28', '11', '4', '10',
#        '127', '7', '9', '13', '65', '100', '12', '186', '14', '70', '87',
#        '34', '67', '117', '163', '17', '96', '200'], dtype=object)

# %%
ten.Runs=ten.Runs.astype(int)

# %%
run_b= pd.DataFrame(ten.Runs.value_counts())

# %%
run_b.head()
# Out:
#       count
# Runs
# 1        37
# 3        34
# 2        29
# 6        20
# 4        13

# %%
run_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, 1 to 200
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   count   30 non-null     int64
# dtypes: int64(1)
# memory usage: 360.0 bytes

# %%
run_b.shape
# Out:
# (30, 1)

# %%
run_b.index.astype('int64')
# Out:
# Index([  1,   3,   2,   6,   4,   5,   8,   9,  11,  10,   7,  12,  13, 127,
#        100,  82,  14,  34,  96,  17, 163, 117,  67,  70,  87,  28, 186,  65,
#         26, 200],
#       dtype='int64', name='Runs')

# %%
plt.hist(ten.Runs,bins=30,edgecolor='black')
plt.show()

# %%
plt.hist(run_b['count'],edgecolor='black')
plt.show()

# %%
plt.bar(run_b.index, run_b['count'])
plt.show()

# %%
ten['4s'].value_counts()
# Out:
# 4s
# 2     28
# 3     25
# 1     18
# 4     17
# 5     16
# 9     15
# 6     14
# 8     13
# 7     13
# 10    11
# 13     8
# 0      6
# 12     5
# 15     4
# 11     4
# 16     4
# 14     3
# 19     2
# 20     1
# 17     1
# 25     1
# Name: count, dtype: int64

# %%
ten['4s'].unique()
# Out:
# array(['5', '1', '3', '7', '2', '8', '6', '0', '4', '15', '9', '13', '10',
#        '14', '11', '20', '12', '19', '17', '16', '25'], dtype=object)

# %%
ten['4s']=ten['4s'].astype(int)

# %%
from scipy import stats as st

# %%
st.mode(ten['4s'])
# Out:
# ModeResult(mode=2, count=28)

# %%
np.median(ten['4s'])
# Out:
# 5.0

# %%
fours= pd.DataFrame(ten['4s'].value_counts())
fours.head()
# Out:
#     count
# 4s
# 2      28
# 3      25
# 1      18
# 4      17
# 5      16

# %%
plt.bar(fours.index, fours['count'])
plt.show()

# %%
plt.hist(ten['4s'], edgecolor='black', bins=28)
plt.show()

# %%
ten1=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\tendulkar_ODI.csv")

# %%
ten1['4s'].unique()
# Out:
# array(['0', '5', '1', '3', '7', '-', '2', '8', '6', '4', '15', '9', '13',
#        '10', '14', '11', '20', '12', '19', '17', '16', '25'], dtype=object)

# %%
ten1=ten1[~(ten1['4s']=='-')]

# %%
ten1['4s']=ten1['4s'].astype(int)

# %%
st.mode(ten1['4s'])
# Out:
# ModeResult(mode=0, count=69)

# %%
ten1['4s'].unique()
# Out:
# array([ 0,  5,  1,  3,  7,  2,  8,  6,  4, 15,  9, 13, 10, 14, 11, 20, 12,
#        19, 17, 16, 25])

# %%
plt.hist(ten1['4s'], edgecolor='black',bins=28)
plt.show()

# %%
pop=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\popularity.csv")

# %%
pop
# Out:
#                                                      url   timedelta  \
# 0      http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1      http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2      http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3      http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4       http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
# ...                                                  ...         ...
# 39639  http://mashable.com/2014/12/27/samsung-app-aut...         8.0
# 39640  http://mashable.com/2014/12/27/seth-rogen-jame...         8.0
# 39641  http://mashable.com/2014/12/27/son-pays-off-mo...         8.0
# 39642     http://mashable.com/2014/12/27/ukraine-blasts/         8.0
# 39643  http://mashable.com/2014/12/27/youtube-channel...         8.0
#
#         n_tokens_title   n_tokens_content   n_unique_tokens  \
# 0                 12.0              219.0          0.663594
# ...

# %%
pop.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
pop[' num_keywords'].describe()
# Out:
# count    39644.000000
# mean         7.223767
# std          1.909130
# min          1.000000
# 25%          6.000000
# 50%          7.000000
# 75%          9.000000
# max         10.000000
# Name:  num_keywords, dtype: float64

# %%
st.mode(pop[' num_keywords'])
# Out:
# ModeResult(mode=7.0, count=7322)

# %%
np.mean(pop[' shares'])
# Out:
# 3395.3801836343455

# %%
pop[' shares'].describe()
# Out:
# count     39644.000000
# mean       3395.380184
# std       11626.950749
# min           1.000000
# 25%         946.000000
# 50%        1400.000000
# 75%        2800.000000
# max      843300.000000
# Name:  shares, dtype: float64

# %%
np.percentile(pop[' shares'],78)
# Out:
# 3100.0

# %%
np.percentile(pop[' shares'],70)
# Out:
# 2300.0

# %%
np.percentile(pop[' shares'],80)
# Out:
# 3400.0

# %%
s95= np.percentile(pop[' shares'],95)

# %%
s95
# Out:
# 10800.0

# %%
pop=pop[~(pop[' shares']>s95)]

# %%
pop[' shares'].describe()
# Out:
# count    37663.000000
# mean      2074.334387
# std       1871.814139
# min          1.000000
# 25%        927.000000
# 50%       1400.000000
# 75%       2400.000000
# max      10800.000000
# Name:  shares, dtype: float64

# %%
k=np.var(pop[' shares'])

# %%
k**(0.5)
# Out:
# 1871.7892891699355

# %%
pop.shape
# Out:
# (37663, 61)

# %%
39644-37663
# Out:
# 1981

# %%
1981/39644
# Out:
# 0.04996973060236101

# %%
gold=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\EDA_Gold_Silver_prices.csv")

# %%
gold
# Out:
#       Month  SilverPrice  GoldPrice
# 0    Mar-97       186.48   12619.24
# 1    Apr-97       170.65   12338.59
# 2    May-97       170.44   12314.94
# 3    Jun-97       169.96   12202.78
# 4    Jul-97       155.80   11582.07
# ..      ...          ...        ...
# 236  Nov-16      1175.45   83622.54
# 237  Dec-16      1115.72   78583.48
# 238  Jan-17      1151.15   81191.05
# 239  Feb-17      1203.35   82818.17
# 240  Mar-17      1162.15   81169.45
#
# [241 rows x 3 columns]

# %%
gold['GoldPrice'].corr(gold['SilverPrice'])
# Out:
# 0.9542559570539775

# %%
gold1= gold.drop(['Month'], axis='columns')

# %%
gold1.head()
# Out:
#    SilverPrice  GoldPrice
# 0       186.48   12619.24
# 1       170.65   12338.59
# 2       170.44   12314.94
# 3       169.96   12202.78
# 4       155.80   11582.07

# %%
g_corr=gold1.corr()

# %%
sns.heatmap(g_corr, annot=True)
plt.show()

# %%
gold['Month'].unique()
# Out:
# array(['Mar-97', 'Apr-97', 'May-97', 'Jun-97', 'Jul-97', 'Aug-97',
#        'Sep-97', 'Oct-97', 'Nov-97', 'Dec-97', 'Jan-98', 'Feb-98',
#        'Mar-98', 'Apr-98', 'May-98', 'Jun-98', 'Jul-98', 'Aug-98',
#        'Sep-98', 'Oct-98', 'Nov-98', 'Dec-98', 'Jan-99', 'Feb-99',
#        'Mar-99', 'Apr-99', 'May-99', 'Jun-99', 'Jul-99', 'Aug-99',
#        'Sep-99', 'Oct-99', 'Nov-99', 'Dec-99', 'Jan-00', 'Feb-00',
#        'Mar-00', 'Apr-00', 'May-00', 'Jun-00', 'Jul-00', 'Aug-00',
#        'Sep-00', 'Oct-00', 'Nov-00', 'Dec-00', 'Jan-01', 'Feb-01',
#        'Mar-01', 'Apr-01', 'May-01', 'Jun-01', 'Jul-01', 'Aug-01',
#        'Sep-01', 'Oct-01', 'Nov-01', 'Dec-01', 'Jan-02', 'Feb-02',
#        'Mar-02', 'Apr-02', 'May-02', 'Jun-02', 'Jul-02', 'Aug-02',
#        'Sep-02', 'Oct-02', 'Nov-02', 'Dec-02', 'Jan-03', 'Feb-03',
#        'Mar-03', 'Apr-03', 'May-03', 'Jun-03', 'Jul-03', 'Aug-03',
#        'Sep-03', 'Oct-03', 'Nov-03', 'Dec-03', 'Jan-04', 'Feb-04',
# ...

# %%
gold['Month'] = pd.to_datetime(gold['Month'], errors='coerce')
# Out:
# C:\Users\GCORPUSER70-PC\AppData\Local\Temp\ipykernel_18628\1112672250.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   gold['Month'] = pd.to_datetime(gold['Month'], errors='coerce')

# %%
gold
# Out:
#          Month  SilverPrice  GoldPrice
# 0   1997-03-01       186.48   12619.24
# 1   1997-04-01       170.65   12338.59
# 2   1997-05-01       170.44   12314.94
# 3   1997-06-01       169.96   12202.78
# 4   1997-07-01       155.80   11582.07
# ..         ...          ...        ...
# 236        NaT      1175.45   83622.54
# 237        NaT      1115.72   78583.48
# 238        NaT      1151.15   81191.05
# 239        NaT      1203.35   82818.17
# 240        NaT      1162.15   81169.45
#
# [241 rows x 3 columns]

# %%
gold['Year']= pd.DatetimeIndex(gold['Month']).year

# %%
gold
# Out:
#          Month  SilverPrice  GoldPrice    Year
# 0   1997-03-01       186.48   12619.24  1997.0
# 1   1997-04-01       170.65   12338.59  1997.0
# 2   1997-05-01       170.44   12314.94  1997.0
# 3   1997-06-01       169.96   12202.78  1997.0
# 4   1997-07-01       155.80   11582.07  1997.0
# ..         ...          ...        ...     ...
# 236        NaT      1175.45   83622.54     NaN
# 237        NaT      1115.72   78583.48     NaN
# 238        NaT      1151.15   81191.05     NaN
# 239        NaT      1203.35   82818.17     NaN
# 240        NaT      1162.15   81169.45     NaN
#
# [241 rows x 4 columns]

# %%
gold3= gold[gold['Year']==1997.0]

# %%
gold3
# Out:
#        Month  SilverPrice  GoldPrice    Year
# 0 1997-03-01       186.48   12619.24  1997.0
# 1 1997-04-01       170.65   12338.59  1997.0
# 2 1997-05-01       170.44   12314.94  1997.0
# 3 1997-06-01       169.96   12202.78  1997.0
# 4 1997-07-01       155.80   11582.07  1997.0
# 5 1997-08-01       162.16   11640.38  1997.0
# 6 1997-09-01       172.13   11755.57  1997.0
# 7 1997-10-01       181.57   11769.89  1997.0
# 8 1997-11-01       187.99   11370.19  1997.0
# 9 1997-12-01       224.16   11324.79  1997.0

# %%
gold.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        34 non-null     datetime64[ns]
#  1   SilverPrice  241 non-null    float64
#  2   GoldPrice    241 non-null    float64
#  3   Year         34 non-null     float64
# dtypes: datetime64[ns](1), float64(3)
# memory usage: 7.7 KB

# %%
gold5=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\EDA_Gold_Silver_prices.csv")

# %%
gold5
# Out:
#           Month  SilverPrice  GoldPrice
# 0      3/1/1997       186.48   12619.24
# 1      4/1/1997       170.65   12338.59
# 2      5/1/1997       170.44   12314.94
# 3      6/1/1997       169.96   12202.78
# 4      7/1/1997       155.80   11582.07
# ..          ...          ...        ...
# 236  11/16/2024      1175.45   83622.54
# 237  12/16/2024      1115.72   78583.48
# 238   1/17/2024      1151.15   81191.05
# 239   2/17/2024      1203.35   82818.17
# 240   3/17/2024      1162.15   81169.45
#
# [241 rows x 3 columns]

# %%
gold5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        241 non-null    object
#  1   SilverPrice  241 non-null    float64
#  2   GoldPrice    241 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 5.8+ KB

# %%
gold5['Year']= pd.DatetimeIndex(gold5['Month']).year

# %%
y2008= gold[gold['Year']==1998]

# %%
y2008
# Out:
#         Month  SilverPrice  GoldPrice    Year
# 10 1998-01-01       230.08   11378.25  1998.0
# 11 1998-02-01       261.75   11576.23  1998.0
# 12 1998-03-01       243.81   11690.84  1998.0
# 13 1998-04-01       249.37   12225.02  1998.0
# 14 1998-05-01       225.54   12075.24  1998.0
# 15 1998-06-01       222.24   12349.86  1998.0
# 16 1998-07-01       232.46   12450.03  1998.0
# 17 1998-08-01       220.73   12142.73  1998.0
# 18 1998-09-01       213.74   12287.69  1998.0
# 19 1998-10-01       211.80   12531.16  1998.0
# 20 1998-11-01       211.21   12463.97  1998.0
# 21 1998-12-01       207.96   12412.18  1998.0

# %%
y2008['GoldPrice'].corr(y2008['SilverPrice'])
# Out:
# -0.6366058994090342

# %%
gs=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\EDA_Gold_Silver_prices (1).csv")

# %%
gs
# Out:
#       Month  SilverPrice  GoldPrice
# 0    Mar-97       186.48   12619.24
# 1    Apr-97       170.65   12338.59
# 2    May-97       170.44   12314.94
# 3    Jun-97       169.96   12202.78
# 4    Jul-97       155.80   11582.07
# ..      ...          ...        ...
# 236  Nov-16      1175.45   83622.54
# 237  Dec-16      1115.72   78583.48
# 238  Jan-17      1151.15   81191.05
# 239  Feb-17      1203.35   82818.17
# 240  Mar-17      1162.15   81169.45
#
# [241 rows x 3 columns]

# %%
gs['Month'] = pd.to_datetime(gs['Month'], format='%b-%y')

# %%
gs
# Out:
#          Month  SilverPrice  GoldPrice
# 0   1997-03-01       186.48   12619.24
# 1   1997-04-01       170.65   12338.59
# 2   1997-05-01       170.44   12314.94
# 3   1997-06-01       169.96   12202.78
# 4   1997-07-01       155.80   11582.07
# ..         ...          ...        ...
# 236 2016-11-01      1175.45   83622.54
# 237 2016-12-01      1115.72   78583.48
# 238 2017-01-01      1151.15   81191.05
# 239 2017-02-01      1203.35   82818.17
# 240 2017-03-01      1162.15   81169.45
#
# [241 rows x 3 columns]

# %%
gs_2008 = gs[gs['Month'].dt.year == 2008]

# %%
gs_2008
# Out:
#          Month  SilverPrice  GoldPrice
# 130 2008-01-01       632.29   35025.78
# 131 2008-02-01       701.87   36642.46
# 132 2008-03-01       775.49   39082.77
# 133 2008-04-01       700.96   36416.00
# 134 2008-05-01       718.20   37435.38
# 135 2008-06-01       729.63   38087.88
# 136 2008-07-01       773.80   40256.56
# 137 2008-08-01       625.97   36026.85
# 138 2008-09-01       555.58   37815.02
# 139 2008-10-01       507.20   39235.79
# 140 2008-11-01       483.55   37284.82
# 141 2008-12-01       501.82   39696.27

# %%
correlation_2008 = gs_2008['GoldPrice'].corr(gs_2008['SilverPrice'])

# Round the correlation to two decimal places
correlation_2008_rounded = round(correlation_2008, 2)

# Print the result
print("Correlation between Gold and Silver prices in 2008:", correlation_2008_rounded) # 0.01
# Out:
# Correlation between Gold and Silver prices in 2008: 0.01

# %%
gs1= pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\EDA_Gold_Silver_prices (1).csv")

# %%
gs1['Month']=pd.DatetimeIndex(gs['Month'])

# %%
gs1['Month']=gs1['Month'].dt.year

# %%
gs_2008= gs1[gs1['Month']==2008]

# %%
gs_2008
# Out:
#      Month  SilverPrice  GoldPrice
# 130   2008       632.29   35025.78
# 131   2008       701.87   36642.46
# 132   2008       775.49   39082.77
# 133   2008       700.96   36416.00
# 134   2008       718.20   37435.38
# 135   2008       729.63   38087.88
# 136   2008       773.80   40256.56
# 137   2008       625.97   36026.85
# 138   2008       555.58   37815.02
# 139   2008       507.20   39235.79
# 140   2008       483.55   37284.82
# 141   2008       501.82   39696.27

# %%
round(gs_2008['GoldPrice'].corr(gs_2008['SilverPrice']),2)
# Out:
# 0.01

# %%
sns.jointplot(data=gs1, x=gs1['GoldPrice'], y=gs1['SilverPrice'], hue=gs1['Month'])

# %%
sns.pairplot(gs1[['GoldPrice', 'SilverPrice', 'Month']])

# %%
curr=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\currencies.csv")

# %%
curr
# Out:
#          Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0   July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1   July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2   July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3   July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4   July 08, 2016       9.31350  1.25797       140.510              1.07261
# 5   July 11, 2016       9.29403  1.25769       139.962              1.07050
# 6   July 12, 2016       9.31021  1.25490       143.369              1.05762
# 7   July 13, 2016       9.31350  1.25716       145.178              1.04680
# 8   July 14, 2016       9.30432  1.24695       144.895              1.05236
# 9   July 15, 2016       9.31532  1.25263       147.268              1.04242
# 10  July 18, 2016       9.30354  1.25652           NaN              1.04952
#
# ...

# %%
curr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 52 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Currency                    11 non-null     object
#  1   Chinese Yuan                11 non-null     float64
#  2   Euro                        11 non-null     float64
#  3   Japanese Yen                10 non-null     float64
#  4   U.K. Pound Sterling         11 non-null     float64
#  5   U.S. Dollar                 11 non-null     float64
#  6   Algerian Dinar              9 non-null      float64
#  7   Australian Dollar           11 non-null     float64
#  8   Bahrain Dinar               11 non-null     float64
#  9   Botswana Pula               9 non-null      float64
#  10  Brazilian Real              11 non-null     float64
#  11  Brunei Dollar               10 non-null     float64
#  12  Canadian Dollar             10 non-null     float64
# ...

# %%
curr.isnull().sum()
# Out:
# Currency                      0
# Chinese Yuan                  0
# Euro                          0
# Japanese Yen                  1
# U.K. Pound Sterling           0
# U.S. Dollar                   0
# Algerian Dinar                2
# Australian Dollar             0
# Bahrain Dinar                 0
# Botswana Pula                 2
# Brazilian Real                0
# Brunei Dollar                 1
# Canadian Dollar               1
# Chilean Peso                  0
# Colombian Peso                0
# Czech Koruna                  3
# Danish Krone                  0
# Hungarian Forint              0
# Icelandic Krona               0
# Indian Rupee                  2
# Indonesian Rupiah             4
# Iranian Rial                  5
# Israeli New Sheqel            0
# Kazakhstani Tenge             3
# Korean Won                    0
# Kuwaiti Dinar                 5
# Libyan Dinar                  0
# Malaysian Ringgit             3
# Mauritian Rupee               2
# ...

# %%
curr.columns
# Out:
# Index(['Currency', 'Chinese Yuan', 'Euro', 'Japanese Yen',
#        'U.K. Pound Sterling', 'U.S. Dollar', 'Algerian Dinar',
#        'Australian Dollar', 'Bahrain Dinar', 'Botswana Pula', 'Brazilian Real',
#        'Brunei Dollar', 'Canadian Dollar', 'Chilean Peso', 'Colombian Peso',
#        'Czech Koruna', 'Danish Krone', 'Hungarian Forint', 'Icelandic Krona',
#        'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial',
#        'Israeli New Sheqel', 'Kazakhstani Tenge', 'Korean Won',
#        'Kuwaiti Dinar', 'Libyan Dinar', 'Malaysian Ringgit', 'Mauritian Rupee',
#        'Mexican Peso', 'Nepalese Rupee', 'New Zealand Dollar',
#        'Norwegian Krone', 'Rial Omani', 'Pakistani Rupee', 'Nuevo Sol',
#        'Philippine Peso', 'Polish Zloty', 'Qatar Riyal', 'Russian Ruble',
#        'Saudi Arabian Riyal', 'Singapore Dollar', 'South African Rand',
#        'Sri Lanka Rupee', 'Swedish Krona', 'Swiss Franc', 'Thai Baht',
# ...

# %%
med=np.mean(curr['Japanese Yen'])     
curr['Japanese Yen']=curr['Japanese Yen'].fillna(med)

# %%
med=np.mean(curr['Indian Rupee'])     
curr['Indian Rupee']=curr['Indian Rupee'].fillna(med)

# %%
curr
# Out:
#          Currency  Chinese Yuan     Euro  Japanese Yen  U.K. Pound Sterling  \
# 0   July 01, 2016       9.29446  1.25367       143.645              1.05054
# 1   July 05, 2016       9.31515  1.25322       142.715              1.06143
# 2   July 06, 2016       9.31697  1.25834       140.540              1.07300
# 3   July 07, 2016       9.31315  1.25737       140.640              1.06911
# 4   July 08, 2016       9.31350  1.25797       140.510              1.07261
# 5   July 11, 2016       9.29403  1.25769       139.962              1.07050
# 6   July 12, 2016       9.31021  1.25490       143.369              1.05762
# 7   July 13, 2016       9.31350  1.25716       145.178              1.04680
# 8   July 14, 2016       9.30432  1.24695       144.895              1.05236
# 9   July 15, 2016       9.31532  1.25263       147.268              1.04242
# 10  July 18, 2016       9.30354  1.25652           NaN              1.04952
#
# ...

# %%
curr.isnull().sum()
# Out:
# Currency                      0
# Chinese Yuan                  0
# Euro                          0
# Japanese Yen                  1
# U.K. Pound Sterling           0
# U.S. Dollar                   0
# Algerian Dinar                2
# Australian Dollar             0
# Bahrain Dinar                 0
# Botswana Pula                 2
# Brazilian Real                0
# Brunei Dollar                 1
# Canadian Dollar               1
# Chilean Peso                  0
# Colombian Peso                0
# Czech Koruna                  3
# Danish Krone                  0
# Hungarian Forint              0
# Icelandic Krona               0
# Indian Rupee                  2
# Indonesian Rupiah             4
# Iranian Rial                  5
# Israeli New Sheqel            0
# Kazakhstani Tenge             3
# Korean Won                    0
# Kuwaiti Dinar                 5
# Libyan Dinar                  0
# Malaysian Ringgit             3
# Mauritian Rupee               2
# ...

# %%
curr.columns
# Out:
# Index(['Currency', 'Chinese Yuan', 'Euro', 'Japanese Yen',
#        'U.K. Pound Sterling', 'U.S. Dollar', 'Algerian Dinar',
#        'Australian Dollar', 'Bahrain Dinar', 'Botswana Pula', 'Brazilian Real',
#        'Brunei Dollar', 'Canadian Dollar', 'Chilean Peso', 'Colombian Peso',
#        'Czech Koruna', 'Danish Krone', 'Hungarian Forint', 'Icelandic Krona',
#        'Indian Rupee', 'Indonesian Rupiah', 'Iranian Rial',
#        'Israeli New Sheqel', 'Kazakhstani Tenge', 'Korean Won',
#        'Kuwaiti Dinar', 'Libyan Dinar', 'Malaysian Ringgit', 'Mauritian Rupee',
#        'Mexican Peso', 'Nepalese Rupee', 'New Zealand Dollar',
#        'Norwegian Krone', 'Rial Omani', 'Pakistani Rupee', 'Nuevo Sol',
#        'Philippine Peso', 'Polish Zloty', 'Qatar Riyal', 'Russian Ruble',
#        'Saudi Arabian Riyal', 'Singapore Dollar', 'South African Rand',
#        'Sri Lanka Rupee', 'Swedish Krona', 'Swiss Franc', 'Thai Baht',
# ...

# %%
curr['Indian Rupee'].corr(curr['Euro'])
# Out:
# 0.24385071994533072

# %%
curr['Indian Rupee'].corr(curr['Chinese Yuan'])
# Out:
# 0.30405003985973084

# %%
curr['Indian Rupee'].corr(curr['Japanese Yen'])
# Out:
# -0.27012349155025495

# %%
curr['Indian Rupee'].corr(curr['U.K. Pound Sterling'])
# Out:
# 0.31468061473571973

# %%
curr['Indian Rupee'].corr(curr['Australian Dollar'])
# Out:
# 0.9214754518981337

# %%
curr['Indian Rupee'].corr(curr['U.S. Dollar'])
# Out:
# 0.8728617382644617

# %%
new=curr[['Indian Rupee', 'U.S. Dollar', 'Australian Dollar', 'U.K. Pound Sterling', 'Japanese Yen', 'Chinese Yuan', 'Euro']].copy()

# %%
new
# Out:
#     Indian Rupee  U.S. Dollar  Australian Dollar  U.K. Pound Sterling  \
# 0        94.1451      1.39596            1.87126              1.05054
# 1        94.1513      1.39684            1.85825              1.06143
# 2            NaN      1.39286            1.87313              1.07300
# 3        94.0345      1.39316            1.85236              1.06911
# 4        93.9408      1.39257            1.85974              1.07261
# 5        93.3027      1.38962            1.83836              1.07050
# 6        93.4641      1.39194            1.83439              1.05762
# 7        93.5445      1.39193            1.83101              1.04680
# 8        93.0917      1.39122            1.82791              1.05236
# 9            NaN      1.39392            1.82786              1.04242
# 10       93.1923      1.38883            1.82741              1.04952
#
#     Japanese Yen  Chinese Yuan     Euro
# 0        143.645       9.29446  1.25367
# 1        142.715       9.31515  1.25322
# ...

# %%
cs=new.corr()
cs
# Out:
#                      Indian Rupee  U.S. Dollar  Australian Dollar  \
# Indian Rupee             1.000000     0.872862           0.921475
# U.S. Dollar              0.872862     1.000000           0.607010
# Australian Dollar        0.921475     0.607010           1.000000
# U.K. Pound Sterling      0.314681    -0.042303           0.579213
# Japanese Yen            -0.270123     0.210295          -0.582032
# Chinese Yuan             0.304050     0.291582           0.077983
# Euro                     0.243851    -0.210587           0.331588
#
#                      U.K. Pound Sterling  Japanese Yen  Chinese Yuan      Euro
# Indian Rupee                    0.314681     -0.270123      0.304050  0.243851
# U.S. Dollar                    -0.042303      0.210295      0.291582 -0.210587
# Australian Dollar               0.579213     -0.582032      0.077983  0.331588
# U.K. Pound Sterling             1.000000     -0.970308      0.108695  0.531150
# ...

# %%
sns.heatmap(cs, annot=True)
# Out:
# <Axes: >

# %%
cust_rating= pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\rating_final (1).csv")

# %%
cust_rating
# Out:
#      userID  placeID  rating  food_rating  service_rating
# 0     U1077   135085       2            2               2
# 1     U1077   135038       2            2               1
# 2     U1077   132825       2            2               2
# 3     U1077   135060       1            2               2
# 4     U1068   135104       1            1               2
# ...     ...      ...     ...          ...             ...
# 1249  U1043   132630       1            1               1
# 1250  U1011   132715       1            1               0
# 1251  U1068   132733       1            1               0
# 1252  U1068   132594       1            1               1
# 1253  U1068   132660       0            0               0
#
# [1254 rows x 5 columns]

# %%
cust_rating['avg_rating']=round((cust_rating['rating']+cust_rating['food_rating'] + cust_rating['service_rating'])/3)

# %%
cust_rating
# Out:
#      userID  placeID  rating  food_rating  service_rating  avg_rating
# 0     U1077   135085       2            2               2         2.0
# 1     U1077   135038       2            2               1         2.0
# 2     U1077   132825       2            2               2         2.0
# 3     U1077   135060       1            2               2         2.0
# 4     U1068   135104       1            1               2         1.0
# ...     ...      ...     ...          ...             ...         ...
# 1249  U1043   132630       1            1               1         1.0
# 1250  U1011   132715       1            1               0         1.0
# 1251  U1068   132733       1            1               0         1.0
# 1252  U1068   132594       1            1               1         1.0
# 1253  U1068   132660       0            0               0         0.0
#
# [1254 rows x 6 columns]

# %%
cri=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\odi-batting.csv")

# %%
cri
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110  01-09-2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82  10-07-2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57  01-07-2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5  10-03-1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3  03-02-1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls
# 0         Sharjah CA Stadium        Canada    121
# 1                 VRA Ground   Netherlands    111
# ...

# %%
cri['MatchDate']= pd.DatetimeIndex(cri['MatchDate'])

# %%
cri['year']=pd.DatetimeIndex(cri['MatchDate']).year

# %%
cri
# Out:
#            Country               Player  Runs  MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118 2010-02-16     Tue
# 1      Afghanistan     Mohammad Shahzad   110 2009-01-09     Tue
# 2      Afghanistan     Mohammad Shahzad   100 2010-08-16     Mon
# 3      Afghanistan     Mohammad Shahzad    82 2010-10-07     Sat
# 4      Afghanistan     Mohammad Shahzad    57 2010-01-07     Thu
# ...            ...                  ...   ...        ...     ...
# 50279     Zimbabwe        Kevin G Duers     5 1992-10-03     Tue
# 50280     Zimbabwe        Kevin G Duers     2 1992-03-14     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3 1993-03-02     Wed
# 50282     Zimbabwe       Brian V Vitori     3 2011-09-14     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1 2004-05-29     Sat
#
#                       Ground        Versus  Balls  year
# 0         Sharjah CA Stadium        Canada    121  2010
# 1                 VRA Ground   Netherlands    111  2009
# ...

# %%
cr_ind= cri[(cri['Country']=='India') & (cri['Runs']>99)]

# %%
cr_ind
# Out:
#       Country              Player  Runs  MatchDate Weekday  \
# 13601   India  Sachin R Tendulkar   200 2010-02-24     Wed
# 13602   India  Sachin R Tendulkar   186 1999-08-11     Mon
# 13603   India  Sachin R Tendulkar   175 2009-05-11     Thu
# 13604   India  Sachin R Tendulkar   163 2009-08-03     Sun
# 13605   India  Sachin R Tendulkar   152 2003-02-23     Sun
# ...       ...                 ...   ...        ...     ...
# 18180   India      Yusuf K Pathan   123 2010-07-12     Tue
# 18181   India      Yusuf K Pathan   105 2011-01-23     Sun
# 18244   India         Raman Lamba   102 1986-07-10     Tue
# 18467   India    Woorkeri V Raman   114 1992-11-12     Fri
# 18636   India       Chetan Sharma   101 1989-10-25     Wed
#
#                                    Ground        Versus  Balls  year
# 13601          Captain Roop Singh Stadium  South Africa    147  2010
# 13602         Lal Bahadur Shastri Stadium   New Zealand    150  1999
# ...

# %%
cr_ind.year.value_counts()
# Out:
# year
# 1998    18
# 1999    15
# 2009    13
# 2010    12
# 2005    11
# 2008    10
# 2003    10
# 2000    10
# 2001     9
# 2002     9
# 1996     8
# 2011     8
# 1994     7
# 1997     7
# 2004     7
# 2006     5
# 2007     5
# 1988     5
# 1987     4
# 1990     3
# 1984     3
# 1993     2
# 1989     2
# 1986     2
# 1991     2
# 1995     1
# 1983     1
# 1992     1
# Name: count, dtype: int64

# %%
ord=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\orders_dimen.csv")

# %%
ord
# Out:
#       Order_ID  Order_Date Order_Priority    Ord_id
# 0            3  13-10-2010            LOW     Ord_1
# 1          293  01-10-2012           HIGH     Ord_2
# 2          483  10-07-2011           HIGH     Ord_3
# 3          515  28-08-2010  NOT SPECIFIED     Ord_4
# 4          613  17-06-2011           HIGH     Ord_5
# ...        ...         ...            ...       ...
# 5501     47360  08-10-2010  NOT SPECIFIED  Ord_5502
# 5502     52706  09-07-2012            LOW  Ord_5503
# 5503     54279  30-07-2011           HIGH  Ord_5504
# 5504     55558  09-08-2010         MEDIUM  Ord_5505
# 5505     56581  08-02-2009           HIGH  Ord_5506
#
# [5506 rows x 4 columns]

# %%
ord['year']= pd.DatetimeIndex(ord['Order_Date']).year

# %%
ord['month']= pd.DatetimeIndex(ord['Order_Date']).month

# %%
ord['day']= pd.DatetimeIndex(ord['Order_Date']).day

# %%
ord
# Out:
#       Order_ID  Order_Date Order_Priority    Ord_id  year  month  day
# 0            3  13-10-2010            LOW     Ord_1  2010     10   13
# 1          293  01-10-2012           HIGH     Ord_2  2012      1   10
# 2          483  10-07-2011           HIGH     Ord_3  2011     10    7
# 3          515  28-08-2010  NOT SPECIFIED     Ord_4  2010      8   28
# 4          613  17-06-2011           HIGH     Ord_5  2011      6   17
# ...        ...         ...            ...       ...   ...    ...  ...
# 5501     47360  08-10-2010  NOT SPECIFIED  Ord_5502  2010      8   10
# 5502     52706  09-07-2012            LOW  Ord_5503  2012      9    7
# 5503     54279  30-07-2011           HIGH  Ord_5504  2011      7   30
# 5504     55558  09-08-2010         MEDIUM  Ord_5505  2010      9    8
# 5505     56581  08-02-2009           HIGH  Ord_5506  2009      8    2
#
# [5506 rows x 7 columns]

# %%
grades= pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\grades.csv")

# %%
grades
# Out:
#                                             submission        submit_time
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44...  01/03/17-20:28:52
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4c...  01/03/17-20:18:21
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-43...  01/03/17-22:37:08
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-49...  01/02/17-21:43:19
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f...  01/03/17-15:27:49
# ..                                                 ...                ...
# 193  https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b...  01/03/17-22:43:12
# 194  https://ckd.upgrad.com/UpGrad/a65694d0-339b-44...  01/09/17-23:59:34
# 195  https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a...  12/19/16-21:44:13
# 196  https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4a...  01/09/17-23:23:06
# 197  https://ckd.upgrad.com/UpGrad/21da378c-75a4-4a...  01/03/17-22:32:38
#
# [198 rows x 2 columns]

# %%
grades['month']= pd.DatetimeIndex(grades['submit_time']).month

# %%
grades['year']= pd.DatetimeIndex(grades['submit_time']).year

# %%
grades['day']= pd.DatetimeIndex(grades['submit_time']).day

# %%
grades['time']= pd.DatetimeIndex(grades['submit_time']).time

# %%
grades
# Out:
#                                             submission        submit_time  \
# 0    https://ckd.upgrad.com/UpGrad/73ba5189-94fd-44...  01/03/17-20:28:52
# 1    https://ckd.upgrad.com/UpGrad/185242ff-7508-4c...  01/03/17-20:18:21
# 2    https://ckd.upgrad.com/UpGrad/a353d129-c100-43...  01/03/17-22:37:08
# 3    https://ckd.upgrad.com/UpGrad/002fc912-faa1-49...  01/02/17-21:43:19
# 4    https://ckd.upgrad.com/UpGrad/25cbc4a4-6d49-4f...  01/03/17-15:27:49
# ..                                                 ...                ...
# 193  https://ckd.upgrad.com/UpGrad/ba485323-bba6-4b...  01/03/17-22:43:12
# 194  https://ckd.upgrad.com/UpGrad/a65694d0-339b-44...  01/09/17-23:59:34
# 195  https://ckd.upgrad.com/UpGrad/c3876ddf-2b2f-4a...  12/19/16-21:44:13
# 196  https://ckd.upgrad.com/UpGrad/2b9732ad-0985-4a...  01/09/17-23:23:06
# 197  https://ckd.upgrad.com/UpGrad/21da378c-75a4-4a...  01/03/17-22:32:38
#
#      month  year  day      time
# 0        1  2017    3  20:28:52
# ...

# %%
nas=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\nas.csv")

# %%
nas
# Out:
#             STUID        State  District Gender       Age  Category  \
# 0     26011001001  Maharashtra         1   Girl  13 years       3.0
# 1     26011001002  Maharashtra         1   Girl  15 years       3.0
# 2     26011001003  Maharashtra         1   Girl  14 years       3.0
# 3     26011001004  Maharashtra         1    Boy  13 years       3.0
# 4     26011001005  Maharashtra         1   Girl  14 years       3.0
# ...           ...          ...       ...    ...       ...       ...
# 8796  26141270036  Maharashtra        14    Boy  13 years       4.0
# 8797  26141270037  Maharashtra        14    Boy  13 years       3.0
# 8798  26141270038  Maharashtra        14    Boy  14 years       4.0
# 8799  26141270039  Maharashtra        14    Boy  13 years       4.0
# 8800  26141270040  Maharashtra        14    Boy  13 years       4.0
#
#       Same.language    Siblings Handicap      Father.edu  ...  \
# 0               2.0   1 sibling       No      Illiterate  ...
# ...

# %%
nas= nas.drop('STUID', axis='columns')

# %%
nas
# Out:
#             State  District Gender       Age  Category  Same.language  \
# 0     Maharashtra         1   Girl  13 years       3.0            2.0
# 1     Maharashtra         1   Girl  15 years       3.0            2.0
# 2     Maharashtra         1   Girl  14 years       3.0            2.0
# 3     Maharashtra         1    Boy  13 years       3.0            2.0
# 4     Maharashtra         1   Girl  14 years       3.0            2.0
# ...           ...       ...    ...       ...       ...            ...
# 8796  Maharashtra        14    Boy  13 years       4.0            1.0
# 8797  Maharashtra        14    Boy  13 years       3.0            1.0
# 8798  Maharashtra        14    Boy  14 years       4.0            1.0
# 8799  Maharashtra        14    Boy  13 years       4.0            NaN
# 8800  Maharashtra        14    Boy  13 years       4.0            NaN
#
#         Siblings Handicap      Father.edu    Mother.edu  ...  \
# 0      1 sibling       No      Illiterate    Illiterate  ...
# ...

# %%
nas.isnull().sum()
# Out:
# State                   0
# District                0
# Gender                  2
# Age                   232
# Category              569
#                      ...
# Help.in.household      44
# Maths..              4611
# Reading..            4574
# Science..            4657
# Social..             4682
# Length: 63, dtype: int64

# %%
nas.State.value_counts()
# Out:
# State
# Maharashtra    8801
# Name: count, dtype: int64

# %%
nas.Gender.value_counts()
# Out:
# Gender
# Boy     4586
# Girl    4213
# Name: count, dtype: int64

# %%
nas['Father.edu'].value_counts()
# Out:
# Father.edu
# Secondary         2549
# Primary           2434
# Illiterate        2034
# Sr secondary       792
# Degree & above     338
# Name: count, dtype: int64

# %%
nas.columns
# Out:
# Index(['State', 'District', 'Gender', 'Age', 'Category', 'Same.language',
#        'Siblings', 'Handicap', 'Father.edu', 'Mother.edu', 'Father.occupation',
#        'Mother.occupation', 'Below.poverty', 'Use.calculator', 'Use.computer',
#        'Use.Internet', 'Use.dictionary', 'Read.other.books', 'X..Books',
#        'Distance', 'Computer.use', 'Library.use', 'Like.school', 'Subjects',
#        'Give.Lang.HW', 'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW',
#        'Correct.Lang.HW', 'Correct.Math.HW', 'Correct.Scie.HW',
#        'Correct.SocS.HW', 'Help.in.Study', 'Private.tuition',
#        'English.is.difficult', 'Read.English', 'Dictionary.to.learn',
#        'Answer.English.WB', 'Answer.English.aloud', 'Maths.is.difficult',
#        'Solve.Maths', 'Solve.Maths.in.groups', 'Draw.geometry',
#        'Explain.answers', 'SocSci.is.difficult', 'Historical.excursions',
#        'Participate.in.SocSci', 'Small.groups.in.SocSci',
# ...

# %%
sns.barplot(data=nas, x='Father.edu', y='Science..')
plt.show()

# %%
ax
# Out:
# array([[<Axes: ylabel='Maths..'>, <Axes: ylabel='Maths..'>],
#        [<Axes: ylabel='Maths..'>, <Axes: ylabel='Maths..'>]], dtype=object)

# %%
sns.boxplot([nas['Maths..'], nas['Reading..'], nas['Science..'], nas['Social..']])
plt.show()

# %%
nas1= pd.DataFrame({'Maths':nas['Maths..'], 'Reading': nas['Reading..'], 'Scinece':nas['Science..'], 'SST': nas['Social..']})

# %%
nas1
# Out:
#       Maths  Reading  Scinece    SST
# 0       NaN    33.33      NaN    NaN
# 1       NaN    62.07      NaN    NaN
# 2       NaN    41.38      NaN    NaN
# 3     29.82      NaN      NaN    NaN
# 4       NaN      NaN    27.27    NaN
# ...     ...      ...      ...    ...
# 8796    NaN      NaN    34.55  30.61
# 8797  16.95    46.67      NaN    NaN
# 8798  24.56    55.17      NaN    NaN
# 8799    NaN      NaN    23.64  34.69
# 8800    NaN      NaN    27.27  30.61
#
# [8801 rows x 4 columns]

# %%
sns.heatmap(nas1.corr(), annot=True, cmap="PiYG")
plt.show()

# %%
sns.heatmap(nas1.corr(), annot=True, cmap="coolwarm")
plt.show()

# %%
sns.heatmap(nas1.corr(), annot=True, cmap="Greens")
plt.show()

# %%
sns.heatmap(nas1.corr(), annot=True, cmap="Blues")
plt.show()

# %%
plt.figsize=[20,20]
sns.lmplot(data=nas, x='Maths..', y='Science..', col='Father.edu' , hue='Mother.edu')
plt.show()

# %%
sns.jointplot(data=nas, x='Maths..', y='Science..', kind='reg', color='red')
plt.show()

# %%
nas
# Out:
#             State  District Gender       Age  Category  Same.language  \
# 0     Maharashtra         1   Girl  13 years       3.0            2.0
# 1     Maharashtra         1   Girl  15 years       3.0            2.0
# 2     Maharashtra         1   Girl  14 years       3.0            2.0
# 3     Maharashtra         1    Boy  13 years       3.0            2.0
# 4     Maharashtra         1   Girl  14 years       3.0            2.0
# ...           ...       ...    ...       ...       ...            ...
# 8796  Maharashtra        14    Boy  13 years       4.0            1.0
# 8797  Maharashtra        14    Boy  13 years       3.0            1.0
# 8798  Maharashtra        14    Boy  14 years       4.0            1.0
# 8799  Maharashtra        14    Boy  13 years       4.0            NaN
# 8800  Maharashtra        14    Boy  13 years       4.0            NaN
#
#         Siblings Handicap      Father.edu    Mother.edu  ...  \
# 0      1 sibling       No      Illiterate    Illiterate  ...
# ...

# %%
sns.countplot(data=nas, x='Father.occupation', hue='Siblings')
plt.xticks(rotation=90)
plt.show()

# %%
nas.columns
# Out:
# Index(['State', 'District', 'Gender', 'Age', 'Category', 'Same.language',
#        'Siblings', 'Handicap', 'Father.edu', 'Mother.edu', 'Father.occupation',
#        'Mother.occupation', 'Below.poverty', 'Use.calculator', 'Use.computer',
#        'Use.Internet', 'Use.dictionary', 'Read.other.books', 'X..Books',
#        'Distance', 'Computer.use', 'Library.use', 'Like.school', 'Subjects',
#        'Give.Lang.HW', 'Give.Math.HW', 'Give.Scie.HW', 'Give.SoSc.HW',
#        'Correct.Lang.HW', 'Correct.Math.HW', 'Correct.Scie.HW',
#        'Correct.SocS.HW', 'Help.in.Study', 'Private.tuition',
#        'English.is.difficult', 'Read.English', 'Dictionary.to.learn',
#        'Answer.English.WB', 'Answer.English.aloud', 'Maths.is.difficult',
#        'Solve.Maths', 'Solve.Maths.in.groups', 'Draw.geometry',
#        'Explain.answers', 'SocSci.is.difficult', 'Historical.excursions',
#        'Participate.in.SocSci', 'Small.groups.in.SocSci',
# ...

# %%
sns.barplot(data=nas, x='Father.occupation', y='Science..')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(data=nas, x='Use.calculator', y='Maths..', hue='Gender')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(data=nas, x='Use.calculator', y='Science..', hue='Gender')
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(data=nas, x='Use.calculator', y='Science..', hue='Below.poverty')
plt.xticks(rotation=90)
plt.show()

# %%
batt=pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\odi-batting.csv")

# %%
batt
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110    1/9/2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82   10/7/2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57    1/7/2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5   10/3/1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3    3/2/1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls
# 0         Sharjah CA Stadium        Canada    121
# 1                 VRA Ground   Netherlands    111
# ...

# %%
batt['Year']=pd.DatetimeIndex(batt['MatchDate']).year

# %%
batt
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110    1/9/2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82   10/7/2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57    1/7/2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5   10/3/1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3    3/2/1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls  Year
# 0         Sharjah CA Stadium        Canada    121  2010
# 1                 VRA Ground   Netherlands    111  2009
# ...

# %%
batt['Century']= batt['Runs'].apply(lambda x: 'Y' if x>99 else 'N')

# %%
batt
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110    1/9/2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82   10/7/2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57    1/7/2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5   10/3/1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3    3/2/1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls  Year Century
# 0         Sharjah CA Stadium        Canada    121  2010       Y
# ...

# %%
batt['SR']= round(batt['Runs']/batt['Balls'],2)

# %%
batt
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110    1/9/2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 3      Afghanistan     Mohammad Shahzad    82   10/7/2010     Sat
# 4      Afghanistan     Mohammad Shahzad    57    1/7/2010     Thu
# ...            ...                  ...   ...         ...     ...
# 50279     Zimbabwe        Kevin G Duers     5   10/3/1992     Tue
# 50280     Zimbabwe        Kevin G Duers     2  14-03-1992     Sat
# 50281     Zimbabwe        Ujesh Ranchod     3    3/2/1993     Wed
# 50282     Zimbabwe       Brian V Vitori     3  14-09-2011     Wed
# 50283     Zimbabwe  Waddington Mwayenga     1  29-05-2004     Sat
#
#                       Ground        Versus  Balls  Year Century    SR
# 0         Sharjah CA Stadium        Canada    121  2010       Y  0.98
# ...

# %%
cen_count=batt[batt.Century=='Y']

# %%
cen_count
# Out:
#            Country               Player  Runs   MatchDate Weekday  \
# 0      Afghanistan     Mohammad Shahzad   118  16-02-2010     Tue
# 1      Afghanistan     Mohammad Shahzad   110    1/9/2009     Tue
# 2      Afghanistan     Mohammad Shahzad   100  16-08-2010     Mon
# 62     Afghanistan      Noor Ali Zadran   114  16-02-2010     Tue
# 87     Afghanistan         Karim Sadiq    114  16-08-2010     Mon
# ...            ...                  ...   ...         ...     ...
# 48682     Zimbabwe     David L Houghton   142  10/10/1987     Sat
# 48737     Zimbabwe       Dion D Ebrahim   121  25-11-2001     Sun
# 49101     Zimbabwe   Charles K Coventry   194  16-08-2009     Sun
# 49208     Zimbabwe        Sean M Ervine   100  24-01-2004     Sat
# 49237     Zimbabwe  Douglas A Marillier   100    5/4/2003     Sat
#
#                              Ground       Versus  Balls  Year Century    SR
# 0                Sharjah CA Stadium       Canada    121  2010       Y  0.98
# ...

# %%
cen_max=cen_count.groupby('Player')['Century'].count()

# %%
cen_max
# Out:
# Player
# Aamir Sohail              5
# Abdool M Samad            1
# Abdul Razzaq              3
# Abraham B de Villiers    11
# Adam C Gilchrist         16
#                          ..
# Xavier M Marshall         1
# Yasir Hameed              3
# Younis Khan               6
# Yusuf K Pathan            2
# Yuvraj Singh             13
# Name: Century, Length: 280, dtype: int64

# %%
cen_max1=cen_count.pivot_table(index='Player', values='Century', aggfunc='count')

# %%
cen_max1
# Out:
#                        Century
# Player
# Aamir Sohail                 5
# Abdool M Samad               1
# Abdul Razzaq                 3
# Abraham B de Villiers       11
# Adam C Gilchrist            16
# ...                        ...
# Xavier M Marshall            1
# Yasir Hameed                 3
# Younis Khan                  6
# Yusuf K Pathan               2
# Yuvraj Singh                13
#
# [280 rows x 1 columns]

# %%
cen_max1.max()
# Out:
# Century    48
# dtype: int64

# %%
for i,j in zip(cen_max1.index, cen_max1.Century):
    if j==48:
        print(i,j)
# Out:
# Sachin R Tendulkar 48

# %%
cen_count['SR'].max()
# Out:
# 2.55

# %%
for i,j,k,l in zip(cen_count.Player, cen_count.SR, cen_count.Runs,cen_count.Balls):
    if j==2.55:
        print(i,j,k,l)
# Out:
# Shahid Afridi 2.55 102 40

# %%
cen_year=cen_count.pivot_table(index='Year', columns='Country', values='Century', aggfunc='count')

# %%
cen_year
# Out:
# Country  Afghanistan  Australia  Bangladesh  Bermuda  Canada  England  India  \
# Year
# 1972             NaN        NaN         NaN      NaN     NaN      1.0    NaN
# 1973             NaN        NaN         NaN      NaN     NaN      1.0    NaN
# 1974             NaN        NaN         NaN      NaN     NaN      1.0    NaN
# 1975             NaN        1.0         NaN      NaN     NaN      2.0    NaN
# 1976             NaN        NaN         NaN      NaN     NaN      NaN    NaN
# 1977             NaN        1.0         NaN      NaN     NaN      1.0    NaN
# 1978             NaN        NaN         NaN      NaN     NaN      2.0    NaN
# 1979             NaN        NaN         NaN      NaN     NaN      2.0    NaN
# 1980             NaN        2.0         NaN      NaN     NaN      1.0    NaN
# 1981             NaN        2.0         NaN      NaN     NaN      NaN    NaN
# 1982             NaN        1.0         NaN      NaN     NaN      1.0    NaN
# ...

# %%
cen_year.max()
# Out:
# Country    75
# dtype: int64

# %%
k=[]
for i in cen_year.index:
    k.append((i,cen_year.loc[i,:].max()))

# %%
print(k)
# Out:
# [(1972, 1.0), (1973, 1.0), (1974, 1.0), (1975, 3.0), (1976, 1.0), (1977, 1.0), (1978, 2.0), (1979, 3.0), (1980, 2.0), (1981, 2.0), (1982, 8.0), (1983, 6.0), (1984, 6.0), (1985, 6.0), (1986, 3.0), (1987, 7.0), (1988, 8.0), (1989, 5.0), (1990, 6.0), (1991, 3.0), (1992, 7.0), (1993, 8.0), (1994, 7.0), (1995, 4.0), (1996, 11.0), (1997, 8.0), (1998, 18.0), (1999, 15.0), (2000, 10.0), (2001, 9.0), (2002, 13.0), (2003, 10.0), (2004, 9.0), (2005, 11.0), (2006, 14.0), (2007, 15.0), (2008, 10.0), (2009, 13.0), (2010, 14.0), (2011, 11.0)]

# %%
from operator import itemgetter
print(sorted(k, key=itemgetter(1,0),reverse=True))
# Out:
# [(1998, 18.0), (2007, 15.0), (1999, 15.0), (2010, 14.0), (2006, 14.0), (2009, 13.0), (2002, 13.0), (2011, 11.0), (2005, 11.0), (1996, 11.0), (2008, 10.0), (2003, 10.0), (2000, 10.0), (2004, 9.0), (2001, 9.0), (1997, 8.0), (1993, 8.0), (1988, 8.0), (1982, 8.0), (1994, 7.0), (1992, 7.0), (1987, 7.0), (1990, 6.0), (1985, 6.0), (1984, 6.0), (1983, 6.0), (1989, 5.0), (1995, 4.0), (1991, 3.0), (1986, 3.0), (1979, 3.0), (1975, 3.0), (1981, 2.0), (1980, 2.0), (1978, 2.0), (1977, 1.0), (1976, 1.0), (1974, 1.0), (1973, 1.0), (1972, 1.0)]

# %%
cen_year
# Out:
# Country  Afghanistan  Australia  Bangladesh  Bermuda  Canada  England  India  \
# Year
# 1972             NaN        NaN         NaN      NaN     NaN      1.0    NaN
# 1973             NaN        NaN         NaN      NaN     NaN      1.0    NaN
# 1974             NaN        NaN         NaN      NaN     NaN      1.0    NaN
# 1975             NaN        1.0         NaN      NaN     NaN      2.0    NaN
# 1976             NaN        NaN         NaN      NaN     NaN      NaN    NaN
# 1977             NaN        1.0         NaN      NaN     NaN      1.0    NaN
# 1978             NaN        NaN         NaN      NaN     NaN      2.0    NaN
# 1979             NaN        NaN         NaN      NaN     NaN      2.0    NaN
# 1980             NaN        2.0         NaN      NaN     NaN      1.0    NaN
# 1981             NaN        2.0         NaN      NaN     NaN      NaN    NaN
# 1982             NaN        1.0         NaN      NaN     NaN      1.0    NaN
# ...

# %%
sns.barplot(data=cen_year, x='Year', y='India', hue='Max')
plt.xticks(rotation=90)
plt.show()

# %%
cen_year_corr=cen_year.corr()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
sns.heatmap(cen_year_corr, cmap='Blues', annot=True)
plt.show()

# %%
c_y= cen_count[['Century']].groupby([cen_count['Year'], cen_count['Country']]).count()

# %%
c_y.reset_index()
# Out:
#      Year       Country  Century
# 0    1972       England        1
# 1    1973       England        1
# 2    1973   West Indies        1
# 3    1974       England        1
# 4    1974   New Zealand        1
# ..    ...           ...      ...
# 272  2011      Pakistan        5
# 273  2011  South Africa        4
# 274  2011     Sri Lanka       11
# 275  2011   West Indies        3
# 276  2011      Zimbabwe        3
#
# [277 rows x 3 columns]

# %%
lar=c_y.nlargest(5,'Century')

# %%
lar
# Out:
#                    Century
# Year Country
# 1998 India              18
# 1999 India              15
# 2007 Australia          15
# 2006 Sri Lanka          14
# 2010 South Africa       14

# %%
most_cen=cen_count[['Century']].groupby(cen_count['Player']).count()

# %%
most_cen
# Out:
#                        Century
# Player
# Aamir Sohail                 5
# Abdool M Samad               1
# Abdul Razzaq                 3
# Abraham B de Villiers       11
# Adam C Gilchrist            16
# ...                        ...
# Xavier M Marshall            1
# Yasir Hameed                 3
# Younis Khan                  6
# Yusuf K Pathan               2
# Yuvraj Singh                13
#
# [280 rows x 1 columns]

# %%
most_cen.reset_index()
# Out:
#                     Player  Century
# 0             Aamir Sohail        5
# 1           Abdool M Samad        1
# 2             Abdul Razzaq        3
# 3    Abraham B de Villiers       11
# 4         Adam C Gilchrist       16
# ..                     ...      ...
# 275      Xavier M Marshall        1
# 276           Yasir Hameed        3
# 277            Younis Khan        6
# 278         Yusuf K Pathan        2
# 279           Yuvraj Singh       13
#
# [280 rows x 2 columns]

# %%
most_cen.nlargest(5,'Century')
# Out:
#                      Century
# Player
# Sachin R Tendulkar        48
# Ricky T Ponting           30
# Sanath T Jayasuriya       28
# Sourav C Ganguly          22
# Herschelle H Gibbs        21

# %%
most_sr=cen_count.pivot_table(index='Player',  values=['SR', 'Century'], aggfunc=({'SR':'mean', 'Century':'count'}))

# %%
most_sr.reset_index()
# Out:
#                     Player  Century        SR
# 0             Aamir Sohail        5  0.846000
# 1           Abdool M Samad        1  1.040000
# 2             Abdul Razzaq        3  1.126667
# 3    Abraham B de Villiers       11  1.235455
# 4         Adam C Gilchrist       16  1.154375
# ..                     ...      ...       ...
# 275      Xavier M Marshall        1  1.330000
# 276           Yasir Hameed        3  0.843333
# 277            Younis Khan        6  1.026667
# 278         Yusuf K Pathan        2  1.390000
# 279           Yuvraj Singh       13  1.141538
#
# [280 rows x 3 columns]

# %%
most_sr.nlargest(10,'Century')
# Out:
#                      Century        SR
# Player
# Sachin R Tendulkar        48  1.012708
# Ricky T Ponting           30  1.007000
# Sanath T Jayasuriya       28  1.165714
# Sourav C Ganguly          22  0.925455
# Herschelle H Gibbs        21  0.981429
# Saeed Anwar               20  0.925000
# Brian C Lara              19  1.093158
# Christopher H Gayle       19  0.989474
# Mark E Waugh              18  0.940556
# Desmond L Haynes          17  0.934706

# %%
m_sr_corr=most_sr['Century'].corr(most_sr['SR'])

# %%
m_sr_corr
# Out:
# 0.050042695270332845

# %%
dft= pd.read_csv(r"C:\Users\GCORPUSER70-PC\Downloads\Session-2(EDA Techniques, Lab Session)-20241027T101554Z-001\Session-2(EDA Techniques, Lab Session)\telecom_churn_data.csv")

# %%
dft.head()
# Out:
#    mobile_number  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0     7000842753        109             0.0             0.0             0.0
# 1     7001865778        109             0.0             0.0             0.0
# 2     7001625959        109             0.0             0.0             0.0
# 3     7001204172        109             0.0             0.0             0.0
# 4     7000142493        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# 0            6/30/2014            7/31/2014            8/31/2014
# 1            6/30/2014            7/31/2014            8/31/2014
# 2            6/30/2014            7/31/2014            8/31/2014
# 3            6/30/2014            7/31/2014            8/31/2014
# 4            6/30/2014            7/31/2014            8/31/2014
#
#   last_date_of_month_9   arpu_6  ...  sachet_3g_9  fb_user_6  fb_user_7  \
# ...

# %%
dft.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99999 entries, 0 to 99998
# Data columns (total 226 columns):
#  #    Column                    Dtype
# ---   ------                    -----
#  0    mobile_number             int64
#  1    circle_id                 int64
#  2    loc_og_t2o_mou            float64
#  3    std_og_t2o_mou            float64
#  4    loc_ic_t2o_mou            float64
#  5    last_date_of_month_6      object
#  6    last_date_of_month_7      object
#  7    last_date_of_month_8      object
#  8    last_date_of_month_9      object
#  9    arpu_6                    float64
#  10   arpu_7                    float64
#  11   arpu_8                    float64
#  12   arpu_9                    float64
#  13   onnet_mou_6               float64
#  14   onnet_mou_7               float64
#  15   onnet_mou_8               float64
#  16   onnet_mou_9               float64
#  17   offnet_mou_6              float64
#  18   offnet_mou_7              float64
# ...

# %%
dft.isnull().sum()
# Out:
# mobile_number        0
# circle_id            0
# loc_og_t2o_mou    1018
# std_og_t2o_mou    1018
# loc_ic_t2o_mou    1018
#                   ...
# aon                  0
# aug_vbc_3g           0
# jul_vbc_3g           0
# jun_vbc_3g           0
# sep_vbc_3g           0
# Length: 226, dtype: int64

# %%
missing_percentage = np.round(100*dft.isnull().sum()/len(dft),2)

# %%
missing_percentage
# Out:
# mobile_number     0.00
# circle_id         0.00
# loc_og_t2o_mou    1.02
# std_og_t2o_mou    1.02
# loc_ic_t2o_mou    1.02
#                   ...
# aon               0.00
# aug_vbc_3g        0.00
# jul_vbc_3g        0.00
# jun_vbc_3g        0.00
# sep_vbc_3g        0.00
# Length: 226, dtype: float64

# %%
missing_percentage = missing_percentage.sort_values(ascending=False)

# %%
missing_percentage
# Out:
# arpu_3g_6            74.85
# night_pck_user_6     74.85
# total_rech_data_6    74.85
# arpu_2g_6            74.85
# max_rech_data_6      74.85
#                      ...
# max_rech_amt_7        0.00
# max_rech_amt_6        0.00
# total_rech_amt_9      0.00
# total_rech_amt_8      0.00
# sep_vbc_3g            0.00
# Length: 226, dtype: float64

# %%
dft.describe(include='O')
# Out:
#        last_date_of_month_6 last_date_of_month_7 last_date_of_month_8  \
# count                 99999                99398                98899
# unique                    1                    1                    1
# top               6/30/2014            7/31/2014            8/31/2014
# freq                  99999                99398                98899
#
#        last_date_of_month_9 date_of_last_rech_6 date_of_last_rech_7  \
# count                 98340               98392               98232
# unique                    1                  30                  31
# top               9/30/2014           6/30/2014           7/31/2014
# freq                  98340               16960               17288
#
#        date_of_last_rech_8 date_of_last_rech_9 date_of_last_rech_data_6  \
# count                96377               95239                    25153
# unique                  31                  30                       30
# ...

# %%
columns = dft.columns

# %%
columns
# Out:
# Index(['mobile_number', 'circle_id', 'loc_og_t2o_mou', 'std_og_t2o_mou',
#        'loc_ic_t2o_mou', 'last_date_of_month_6', 'last_date_of_month_7',
#        'last_date_of_month_8', 'last_date_of_month_9', 'arpu_6',
#        ...
#        'sachet_3g_9', 'fb_user_6', 'fb_user_7', 'fb_user_8', 'fb_user_9',
#        'aon', 'aug_vbc_3g', 'jul_vbc_3g', 'jun_vbc_3g', 'sep_vbc_3g'],
#       dtype='object', length=226)

# %%
id_cols=["mobile_number","circle_id"] 
date_cols=["last_date_of_month_6","last_date_of_month_7","last_date_of_month_8","last_date_of_month_9","date_of_last_rech_6","date_of_last_rech_7","date_of_last_rech_8","date_of_last_rech_9","date_of_last_rech_data_6","date_of_last_rech_data_7","date_of_last_rech_data_8","date_of_last_rech_data_9"] 
cat_cols=['night_pck_user_6', 'night_pck_user_7', 'night_pck_user_8', 'night_pck_user_9', 'fb_user_6', 'fb_user_7', 'fb_user_8', 'fb_user_9' ]

# %%
num_cols= [columns[x] for x not in id_cols + date_cols + cat_cols]
# Out:
#   Cell In[1578], line 1
#     num_cols= [columns[x] for x not in id_cols + date_cols + cat_cols]
#                                 ^
# SyntaxError: invalid syntax

# %%
zero_impute = ['total_rech_data_6', 'total_rech_data_7', 'total_rech_data_8', 'total_rech_data_9', 'av_rech_amt_data_6', 'av_rech_amt_data_7', 'av_rech_amt_data_8', 'av_rech_amt_data_9', 'max_rech_data_6', 'max_rech_data_7', 'max_rech_data_8', 'max_rech_data_9' ] #impute them with value=0 df[zero_impute]=df[zero_impute].apply(lambda x:x.fillna(0))

# %% [markdown]
# z_score=np.abs((df_cleaned_no_outlier["arpu_6"]-df_cleaned_no_outlier["arpu_6"].mean())/df_cleaned_no_outlier["arpu_6"].std()) z_score
